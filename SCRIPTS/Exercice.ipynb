# %%
print("analyse bourse")

# %% [markdown]
# # Let's learning Python

# %%
#Ceci est un commentaire dans la cellule de ce code 
#Python est une programmation orientée objet. On def des variables 
Name = "Noah"
Statut = "GOAT"
print(f"You are {Name}, That's why you are The {Statut}")

stocks = ["AAPL", "MSFT", "GOOGL", "AVGO"]
stocks.append("AMZN")
stocks 
# Ajoute AMZN à la liste
# De plus,
prices = {"AAPL":255.52, "GOOGL":333.33, "MSFT:":459.27, "AVGO": 351.71}
# Out:
# You are Noah, That's why you are The GOAT

# %%
pip install yfinance
# Installer une library (ici Yahoo finance)
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 57.5 MB/s  0:00:00
# ...
# Using cached cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 82.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 74.6 MB/s  0:00:00
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15637 sha256=151fb0b5d1c4dd1b4d29ba4eaaaf5d2b301da688938f7ba98d2f3ff7f165d08b
#   Stored in directory: /home/codespace/.cache/pip/wheels/cc/bd/6f/664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
# Successfully built multitasking
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [yfinance]/20 [yfinance]]rmalizer]
# ...

# %%
# Suite de  Fibonacci 

def get_fibo(n):
    fibo = 1
    for i in range(2,n):
        i = 0
        fibonew = i + fibo
        i = fibo 
        fibonew = fibo

# %%
import yfinance as yf
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# Structure projet Python: 
# Cellule ou l'on importe tous les packages -> Overview dépendances

# %%
pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 69.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 59.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 57.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 70.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
AAPL = yf.download("AAPL","2010-01-01") 
print(AAPL)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2010-01-04    6.418384    6.433080    6.369499    6.400989  493729600
# 2010-01-05    6.429480    6.465769    6.395590    6.436078  601904800
# 2010-01-06    6.327210    6.454972    6.320612    6.429480  552160000
# 2010-01-07    6.315512    6.358100    6.269626    6.350602  477131200
# 2010-01-08    6.357501    6.358101    6.269928    6.307116  447610800
# ...                ...         ...         ...         ...        ...
# 2026-01-26  255.410004  256.559998  249.800003  251.479996   55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013   49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994   41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000   67253000
# ...

# %%
ticker = "AAPL"
data = yf.download(ticker, start="2020-01-01", progress = False, interval = 1m)

data.head() # 5 premières lignes 
data.tail () # 5 dernières lignes
# Out:
#   Cell In[32], line 2
#     data = yf.download(ticker, start="2020-01-01", progress = False, interval = 1m)
#                                                                                 ^
# SyntaxError: invalid decimal literal
